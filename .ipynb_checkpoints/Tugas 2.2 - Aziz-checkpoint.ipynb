# %% [markdown]
# **Task 2.1**
#
# Minggu lalu, Budi sudah membuat suatu function untuk mengubah suhu dari Celcius menjadi Kelvin dan Fahrenheit. Kemudian, Budi berpikir untuk membuat satu function yang bisa digunakan untuk mengkonversi semua jenis suhu.
#
# Budi juga berencana untuk membuat suatu Dictionary yang bisa menyimpan informasi suhu yang sudah dia kumpulkan.
#
# 1. Buat satu function untuk mengkonversi suhu dari satuan Celcius ke Fahrenheit (dan sebaliknya), Celcius ke Kelvin (dan sebaliknya), dan Fahrenheit ke Kelvin (dan sebaliknya). Buat nama functionnya sebagai **Temperature_Conversion**, di mana inputnya adalah
#    - suhu awal
#    - jenis satuan awal
#    - jenis satuan akhir
# Ingat, hanya satu function untuk 6 jenis konversi.
#
# 2. Buat satu dictionary berisi 10 informasi suhu di 10 kota di Indonesia. Informasi tersebut harus mencakup
#     - Nama kota (key)
#     - Provinsi (value)
#     - Suhu dalam 7 hari terakhir (value)
#     - Rata-rata suhu dalam 7 hari terakhir (value)
#     - Koordinat kota tersebut (value)
#
# 3. Uji coba Function yang telah kalian buat (Poin 1) menggunakan beberapa data suhu yang sudah dikumpulkan (Poin 2).

# %% [markdown]
# Note:
# - Temperatur pada suatu kota bisa diperoleh melalui situs web https://openweathermap.org
# - Koordinat pada suatu kota bisa diperoleh melalui Google Maps

# %% [markdown]
# **Tugas Nomor 1 Konversi 6 Jenis Konversi**
#
#
#     Program Konversi Suhu dengan 6 pilihan menu konversi

# %%
def input_menu():
    print("1. Celsius to Fahrenheit")
    print("2. Fahrenheit to Celsius")
    print("3. Celcius to Kelvin")
    print("4. Kelvin to Celcius")
    print("5. Fahrenheit to Kelvin")
    print("6. Kelvin to Fahrenheit")
    print("7. Exit\n")


def input_temperature():
      while True:
        try:
            value = float(input("Enter the temperature in Celsius: "))
            return value
        except ValueError:
            print("Please enter a valid number.")

  
def temperatur_conversion(temp):
    input_menu()
    while True:
        try:
            user_input = int(input("Input your choice: "))
            if user_input in [1, 2, 3, 4, 5, 6, 7]:
                if user_input == 1:
                    conv = (9/5*temp)+32
                    print(f"{temp} °C is {conv} °F")
                elif user_input == 2:
                    conv = ((5/9*temp)-32)
                    print(f"{temp} °F is {conv:.2f} °C")
                elif user_input == 3:
                    conv = temp+273.15
                    print(f"{temp} °C is {conv:.2f} °K")
                elif user_input == 4:
                    conv = temp-273.15
                    print(f"{temp} °K is {conv:.2f} °C")
                elif user_input == 5:
                    conv = (5/9*(temp-32))+273.15
                    print(f"{temp} °F is {conv:.2f} °K")
                elif user_input == 6:
                    conv = (9/5*(temp-32))+273.15
                    print(f"{temp} °K is {conv:.2f} °F")
                elif user_input == 7:
                    break
            else:
                print("Input not valid, please input number")
        except ValueError:
            print("Input not valid, please input number")


if __name__ == "__main__":
    temp = input_temperature()
    temperatur_conversion(temp)
# Out:
# 1. Celsius to Fahrenheit
# 2. Fahrenheit to Celsius
# 3. Celcius to Kelvin
# 4. Kelvin to Celcius
# 5. Fahrenheit to Kelvin
# 6. Kelvin to Fahrenheit
# 7. Exit
#
# 30.0 °C is 86.0 °F
# 30.0 °F is -15.33 °C
# 30.0 °F is -15.33 °C
# 30.0 °C is 303.15 °K
# 30.0 °K is -243.15 °C
# 30.0 °F is 272.04 °K
# 30.0 °K is 269.55 °F

# %% [markdown]
# Tugas Nomor 2 : Membuat dictionary informasi 10 Kota di Indonesia, berisi informasi suhu di 7 hari terakhir, rata-rata suhu di 7 hari terakhir, koordinat kota tersebut. Data temperatur dalam 7 hari diambil dari situs web https://openweathermap.org.

# %%
city_temp = {

    "Surabaya" : {
        "Province": "Jawa Timur",
        "temp_7d": [27.4, 26.4, 27.1, 25.3, 26.5, 26.4, 26.1],
        "ave_temp": round(sum([27.4, 26.4, 27.1, 25.3, 26.5, 26.4, 26.1])/7, 2),
        "coordinates": {-7.257228916825992, 112.74375445827698}
    },

    "Mojokerto" : {
        "Province": "Jawa Timur",
        "temp_7d": [26.4, 25.5, 26.5, 25.2, 26.2, 25.2, 25.3],
        "ave_temp": round(sum([26.4, 25.5, 26.5, 25.2, 26.2, 25.2, 25.3])/7, 2),
        "coordinates": { -7.470211991329571, 112.440603926822}
    },

    "Gresik" : {
        "Province": "Jawa Timur",
        "temp_7d": [27.1, 26.5, 26.5, 26.5, 26.5, 26.5, 26.5],
        "ave_temp": round(sum([27.1, 26.5, 26.5, 26.5, 26.5, 26.5, 26.5])/7, 2),
        "coordinates": {-7.165241200680734, 112.65237629358799}
    },

    "Pasuruan" : {
        "Province": "Jawa Timur",
        "temp_7d": [27.4,25.4, 26.1, 26.3, 26.5, 27.1, 27.2],
        "ave_temp": round(sum([27.4,25.4, 26.1, 26.3, 26.5, 27.1, 27.2])/7, 2),
        "coordinates": {-7.647011769804873, 112.89985912816329}
    },

    "Jombang" : {
        "Province": "Jawa Timur",
        "temp_7d": [26.0,25.5, 26.5,27.1, 26.5, 26.5, 25.7],
        "ave_temp": round(sum([26.0,25.5, 26.5,27.1, 26.5, 26.5, 25.7])/7, 2),
        "coordinates":  {-7.554355900514513, 112.2331687586517}
    },

    "Malang" : {
        "Province": "Jawa Timur",
        "temp_7d": [23.1, 22.4, 24.5, 24.3, 23.6, 25.3, 24.6],
        "ave_temp": round(sum([23.1, 22.4, 24.5, 24.3, 23.6, 25.3, 24.6])/7, 2),
        "coordinates": {-7.967310117537424, 112.63039827139146}
    },

    "Banyuwangi" : {
        "Province": "Jawa Timur",
        "temp_7d": [26.7,],
        "ave_temp": round(sum([26.7, 26.5, 26.5, 26.7, 26.5, 26.1, 26.3])/7, 2),
        "coordinates": {-8.219910974060516, 114.36760067837508},
    },

    "Madiun" : {
        "Province": "Jawa Timur",
        "temp_7d": [25.9, 26.5, 26.5, 26.5, 26.5, 26.5, 26.5],
        "ave_temp": round(sum([25.9, 26.5, 26.5, 26.5, 26.5, 26.5, 26.5])/7, 2),
        "coordinates": {-7.630572324152853, 111.530883812633}
    },

    "Nganjuk" : {
        "Province": "Jawa Timur",
        "temp_7d":[27.5, 25.4, 26.5, 26.3, 26.5, 26.3, 26.5],
        "ave_temp": round(sum([27.5, 25.4, 26.5, 26.3, 26.5, 26.3, 26.5])/7, 2),
        "coordinates": {-7.6044825766855135, 111.89984288105049}
    },

    "Blitar" : {
        "Province": "Jawa Timur",
        "temp_7d": [26.5, 25.5, 26.5, 25.2, 26.2, 25.2, 25.3],
        "ave_temp": round(sum([26.5, 25.5, 26.5, 25.2, 26.2, 25.2, 25.3])/7, 2),
        "coordinates": {-8.094782823976576, 112.15996026888449}
    }
}

#Mengambil nilai rata2 suhu dari setiap kota
sby = city_temp["Surabaya"]["ave_temp"]
mjk = city_temp["Mojokerto"]["ave_temp"]
gsk = city_temp["Gresik"]["ave_temp"]
psu = city_temp["Pasuruan"]["ave_temp"]
jbg = city_temp["Jombang"]["ave_temp"]
mlg = city_temp["Malang"]["ave_temp"]
bwi = city_temp["Banyuwangi"]["ave_temp"]
mdn = city_temp["Madiun"]["ave_temp"]
ngk = city_temp["Nganjuk"]["ave_temp"]
bli = city_temp["Blitar"]["ave_temp"]

kota = list(city_temp.keys())
print(type(kota))
print(kota)
# Out:
# <class 'list'>
# ['Surabaya', 'Mojokerto', 'Gresik', 'Pasuruan', 'Jombang', 'Malang', 'Banyuwangi', 'Madiun', 'Nganjuk', 'Blitar']

# %% [markdown]
# **Tugas No.3 Menggabungkan Fungsi Konversi Temperatur dengan Data Temperatur tiap Kota**

# %%
list_ave = [sby, mjk, gsk, psu, jbg, mlg, bwi, mdn, ngk, bli]


def daftar_kota():
    print("Daftar Kota:")
    for index, city in enumerate(kota, start=1):
        print(f"{index}. {city}")

daftar_kota()
def input_temperature():
      while True:
        try:
            pilihan = int(input("Pilih Kota dari daftar (1-10): "))-1
            if pilihan >= 0 and pilihan < len(list_ave) and pilihan < len(kota):
                print(f"Anda memilih kota: {kota[pilihan]} {list_ave[pilihan]}\n")
                print("Pilih Konversi Suhu:")
                final = list_ave[pilihan]
                return final
        except ValueError:
            print("Please enter a valid number.")
        break


if __name__ == "__main__":
    final = input_temperature()
    temperatur_conversion(final)
# Out:
# Daftar Kota:
# 1. Surabaya
# 2. Mojokerto
# 3. Gresik
# 4. Pasuruan
# 5. Jombang
# 6. Malang
# 7. Banyuwangi
# 8. Madiun
# 9. Nganjuk
# 10. Blitar
# Anda memilih kota: Surabaya 26.46
#
# Pilih Konversi Suhu:
# 1. Celsius to Fahrenheit
# 2. Fahrenheit to Celsius
# 3. Celcius to Kelvin
# 4. Kelvin to Celcius
# 5. Fahrenheit to Kelvin
# 6. Kelvin to Fahrenheit
# 7. Exit
# 26.46 °C is 79.628 °F
# 26.46 °F is -17.30 °C
# 26.46 °C is 299.61 °K
# 26.46 °K is -246.69 °C
# 26.46 °F is 270.07 °K
# 26.46 °K is 263.18 °F

# %% [markdown]
# **Task 2.2**
#
# Sebelumnya, kita sudah mencoba untuk menganalisis nilai maksimum, minimum, mean, dan median dari data Harga Laptop. Kita juga sudah coba melihat bagaimana korelasi antara berat laptop dan harga laptop. Namun, banyak informasi yang berada dalam format non-numerik. Selain itu, kita juga belum memeriksa apakah ada missing value, duplicate value, dan outlier di dalam data kita.
#
# 1. Ubah data angka yang masih berada dalam format string mejadi integer atau float.
# 2. Lakukan proses data cleaning. Periksa apakah ada outlier, missing dan duplicate value, dan hapus atau perbaiki bila memungkinkan.
# 3. Buat boxplot menggunakan subplot untuk minimal 4 variabel numerik yang perlu diperiska outliernya.

# %%
import pandas as pd

df = pd.read_csv("C:/Users/My Latitude/Desktop/basic_DA/laptop_price_dataset.csv")

# %%
df.head()
# Out:
#    Unnamed: 0 Company      Product   TypeName  Inches  \
# 0           0   Apple  MacBook Pro  Ultrabook    13.3
# 1           1   Apple  Macbook Air  Ultrabook    13.3
# 2           2      HP       250 G6   Notebook    15.6
# 3           3   Apple  MacBook Pro  Ultrabook    15.4
# 4           4   Apple  MacBook Pro  Ultrabook    13.3
#
#                      ScreenResolution CPU_Company       CPU_Type  \
# 0  IPS Panel Retina Display 2560x1600       Intel        Core i5
# 1                            1440x900       Intel        Core i5
# 2                   Full HD 1920x1080       Intel  Core i5 7200U
# 3  IPS Panel Retina Display 2880x1800       Intel        Core i7
# 4  IPS Panel Retina Display 2560x1600       Intel        Core i5
#
#    CPU_Frequency (GHz)  RAM (GB)               Memory GPU_Company  \
# 0                  2.3       8.0            128GB SSD       Intel
# 1                  1.8       8.0  128GB Flash Storage       Intel
# ...

# %% [markdown]
# 1a. Mengecek tipe data dari setiap kolom apakah sudah sesuai dengan format yang sesuai. Dari data dibawah didapat data berupa angka sudah sesuai dengan tipe data angka yaitu integer dan float.

# %%
print(df.dtypes)
# Out:
# Unnamed: 0               int64
# Company                 object
# Product                 object
# TypeName                object
# Inches                 float64
# ScreenResolution        object
# CPU_Company             object
# CPU_Type                object
# CPU_Frequency (GHz)    float64
# RAM (GB)               float64
# Memory                  object
# GPU_Company             object
# GPU_Type                object
# OpSys                   object
# Weight (kg)            float64
# Price (Euro)           float64
# dtype: object

# %%
df['RAM (GB)'] = df['RAM (GB)'].astype(float)
print(df["RAM (GB)"])
# Out:
# 0        8.0
# 1        8.0
# 2        8.0
# 3       16.0
# 4        8.0
#         ...
# 1270     4.0
# 1271    16.0
# 1272     2.0
# 1273     6.0
# 1274     4.0
# Name: RAM (GB), Length: 1275, dtype: float64

# %% [markdown]
# 1b. Melakukan pengecekan missing value data dengan fungsi .isnull() didapat data berupa angka 0 berarti tidak ada missing value.

# %%
#Memriksa MIsssing Value
print(df.isnull().sum())
# Out:
# Unnamed: 0             0
# Company                0
# Product                0
# TypeName               0
# Inches                 0
# ScreenResolution       0
# CPU_Company            0
# CPU_Type               0
# CPU_Frequency (GHz)    0
# RAM (GB)               0
# Memory                 0
# GPU_Company            0
# GPU_Type               0
# OpSys                  0
# Weight (kg)            0
# Price (Euro)           0
# dtype: int64

# %% [markdown]
# **1c. Melakukan Pengecekan Duplikasi Data dengan fungsi .duplicated() didapat index data kosong berarti tidak ada duplikasi value.**

# %%
#Memeriksa duplikasi nilai data
duplicate = df[df.duplicated()]
print(duplicate)
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Company, Product, TypeName, Inches, ScreenResolution, CPU_Company, CPU_Type, CPU_Frequency (GHz), RAM (GB), Memory, GPU_Company, GPU_Type, OpSys, Weight (kg), Price (Euro)]
# Index: []

# %% [markdown]
# **1d. Mencari Outlier**
#     Dengan bantuan describe saya ingin mencocokan nilai Q1 dan Q3 apakah sama dengan 25% dan 75% dari data harga.

# %%
print(df.describe())
# Out:
#         Unnamed: 0       Inches  CPU_Frequency (GHz)     RAM (GB)  \
# count  1275.000000  1275.000000          1275.000000  1275.000000
# mean    637.000000    15.022902             2.302980     8.440784
# std     368.205106     1.429470             0.503846     5.097809
# min       0.000000    10.100000             0.900000     2.000000
# 25%     318.500000    14.000000             2.000000     4.000000
# 50%     637.000000    15.600000             2.500000     8.000000
# 75%     955.500000    15.600000             2.700000     8.000000
# max    1274.000000    18.400000             3.600000    64.000000
#
#        Weight (kg)  Price (Euro)
# count  1275.000000   1275.000000
# mean      2.040525   1134.969059
# std       0.669196    700.752504
# min       0.690000    174.000000
# 25%       1.500000    609.000000
# 50%       2.040000    989.000000
# 75%       2.310000   1496.500000
# max       4.700000   6099.000000

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(5, 5))
df.boxplot(column=['Price (Euro)'])
plt.show()

# %% [markdown]
# Dari diagram diatas terdapat outlier harga laptop yang cukup banyak, namun menurut saya hal itu wajar karena dengan harga laptop yang tinggi dengan jumlah permintaan yang sedikit dan diperuntukkan untuk golongan tertentu, ditambah lagi dengan spesifikasi laptop yang sangat berkelas maka data outiler ini tidak berpengaruh.
#
# Namun, saya ingin mencoba untuk melihat bagaimana jika data outier tadi dihilangkan dan ada berapa banyak data yang berada di luar batas

# %%
# Menghitung IQR
Q1 = df['Price (Euro)'].quantile(0.25)
Q3 = df['Price (Euro)'].quantile(0.75)
IQR = Q3 - Q1

# Menentukan batas atas dan batas bawah untuk outliers
lower_bound = Q1 - 1.5*IQR
upper_bound = Q3 + 1.5*IQR

# Menampilkan data yang berada di luar batas
df[(df['Price (Euro)'] < lower_bound) | (df['Price (Euro)'] > upper_bound)]
print(Q1)
print(Q3)
print(lower_bound, upper_bound)
# Out:
# 609.0
# 1496.5
# -722.25 2827.75

# %%
dataset_no_outlier = df[(df['Price (Euro)'] > lower_bound) & (df['Price (Euro)'] > upper_bound)] #tanda perbandingan saya buat lebih besar semua untuk melihat data outlier

# %%
dataset_no_outlier #DATA OUTLIER
# Out:
#       Unnamed: 0 Company             Product     TypeName  Inches  \
# 17            17   Apple         MacBook Pro    Ultrabook    15.4
# 196          196   Razer           Blade Pro       Gaming    17.3
# 204          204    Dell      Precision 7520  Workstation    15.6
# 238          238    Asus   ROG G703VI-E5062T       Gaming    17.3
# 247          247    Asus  Rog G701VIK-BA060T       Gaming    17.3
# 297          297    Dell      Precision 7720  Workstation    17.3
# 517          517    Asus        ROG Zephyrus       Gaming    15.6
# 530          530    Dell        Alienware 17       Gaming    17.3
# 563          563  Lenovo        Thinkpad P71     Notebook    17.3
# 610          610  Lenovo        Thinkpad P51     Notebook    15.6
# 659          659    Dell        Alienware 17       Gaming    17.3
# 723          723    Dell        Alienware 17       Gaming    17.3
# 744          744  Lenovo       Thinkpad P51s  Workstation    15.6
# ...

# %% [markdown]
# Terlihat dari data diatas terdapat 28 Laptop yang memiliki harga mahal memang diperuntukan untuk kepentingan Gaming dan Pekerjaan Berat. Hal ini juga sebanding dengan kualitas layar, CPU dan penyimpanan yang spesifikasinya sangat bagus.

# %%
plt.figure(figsize=(5,5))
dataset_no_outlier.boxplot(column=['Price (Euro)'])
plt.show()

# %%
df.shape[0]-dataset_no_outlier.shape[0]
# Out:
# 28

# %% [markdown]
# Setelah menghilangkan outlier pada data, masih terdapat 3 data yang berada di luar batas dan ini masih normal karena data tersebut tidak berpengaruh terhadap data yang lain. Total jumlah outiler ada 28 dan ini sebenarnya wajar mengingat harga laptop sebanding dengan spesifikasi laptop yang sangat bagus

# %%
fig, axs = plt.subplots(2, 2, figsize=(5, 8))

# Membuat boxplot pada setiap subplot
sns.boxplot(data=df['Inches'], ax=axs[0, 0]).set_title('Inches')
sns.boxplot(data=df['CPU_Frequency (GHz)'], ax=axs[0, 1]).set_title('CPU_Frequency (GHz)')
sns.boxplot(data=df['Weight (kg)'], ax=axs[1, 0]).set_title('Weight (kg)')
sns.boxplot(data=df['Price (Euro)'], ax=axs[1, 1]).set_title('Price (Euro)')

# Menampilkan plot
plt.tight_layout()
plt.show()

# %% [markdown]
# Dari diagram boxplot diatas terdapat outlier dari setiap data, namun menurut saya hal itu wajar karena dengan laptop yang tinggi dengan permintaan yang sedikit dan diperuntukkan untuk golongan tertentu, ditambah lagi dengan spesifikasi laptop yang sangat berkelas. Sehingga data tersebut tidak berpengaruh terhadap data lainnya.
