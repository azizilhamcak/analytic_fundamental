# %%
import pandas as pd

df = pd.read_csv("C:/Users/My Latitude/Desktop/basic_DA/laptop_price_dataset.csv")

# %%
df.head()
# Out:
#    Unnamed: 0 Company      Product   TypeName  Inches  \
# 0           0   Apple  MacBook Pro  Ultrabook    13.3
# 1           1   Apple  Macbook Air  Ultrabook    13.3
# 2           2      HP       250 G6   Notebook    15.6
# 3           3   Apple  MacBook Pro  Ultrabook    15.4
# 4           4   Apple  MacBook Pro  Ultrabook    13.3
#
#                      ScreenResolution CPU_Company       CPU_Type  \
# 0  IPS Panel Retina Display 2560x1600       Intel        Core i5
# 1                            1440x900       Intel        Core i5
# 2                   Full HD 1920x1080       Intel  Core i5 7200U
# 3  IPS Panel Retina Display 2880x1800       Intel        Core i7
# 4  IPS Panel Retina Display 2560x1600       Intel        Core i5
#
#    CPU_Frequency (GHz)  RAM (GB)               Memory GPU_Company  \
# 0                  2.3       8.0            128GB SSD       Intel
# 1                  1.8       8.0  128GB Flash Storage       Intel
# 2                  2.5       8.0            256GB SSD       Intel
# 3                  2.7      16.0            512GB SSD         AMD
# 4                  3.1       8.0            256GB SSD       Intel
#
#                  GPU_Type  OpSys  Weight (kg)  Price (Euro)
# 0  Iris Plus Graphics 640  macOS         1.37       1339.69
# 1        HD Graphics 6000  macOS         1.34        898.94
# 2         HD Graphics 620  No OS         1.86        575.00
# 3          Radeon Pro 455  macOS         1.83       2537.45
# 4  Iris Plus Graphics 650  macOS         1.37       1803.60

# %%
df.describe(include="all")
# Out:
#          Unnamed: 0 Company Product  TypeName       Inches   ScreenResolution  \
# count   1275.000000    1275    1275      1275  1275.000000               1275
# unique          NaN      19     618         6          NaN                 40
# top             NaN    Dell  XPS 13  Notebook          NaN  Full HD 1920x1080
# freq            NaN     291      30       707          NaN                505
# mean     637.000000     NaN     NaN       NaN    15.022902                NaN
# std      368.205106     NaN     NaN       NaN     1.429470                NaN
# min        0.000000     NaN     NaN       NaN    10.100000                NaN
# 25%      318.500000     NaN     NaN       NaN    14.000000                NaN
# 50%      637.000000     NaN     NaN       NaN    15.600000                NaN
# 75%      955.500000     NaN     NaN       NaN    15.600000                NaN
# max     1274.000000     NaN     NaN       NaN    18.400000                NaN
#
#        CPU_Company       CPU_Type  CPU_Frequency (GHz)     RAM (GB)  \
# count         1275           1275          1275.000000  1275.000000
# unique           3             93                  NaN          NaN
# top          Intel  Core i5 7200U                  NaN          NaN
# freq          1214            193                  NaN          NaN
# mean           NaN            NaN             2.302980     8.440784
# std            NaN            NaN             0.503846     5.097809
# min            NaN            NaN             0.900000     2.000000
# 25%            NaN            NaN             2.000000     4.000000
# 50%            NaN            NaN             2.500000     8.000000
# 75%            NaN            NaN             2.700000     8.000000
# max            NaN            NaN             3.600000    64.000000
#
#            Memory GPU_Company         GPU_Type       OpSys  Weight (kg)  \
# count        1275        1275             1275        1275  1275.000000
# unique         39           4              106           9          NaN
# top     256GB SSD       Intel  HD Graphics 620  Windows 10          NaN
# freq          412         704              280        1048          NaN
# mean          NaN         NaN              NaN         NaN     2.040525
# std           NaN         NaN              NaN         NaN     0.669196
# min           NaN         NaN              NaN         NaN     0.690000
# 25%           NaN         NaN              NaN         NaN     1.500000
# 50%           NaN         NaN              NaN         NaN     2.040000
# 75%           NaN         NaN              NaN         NaN     2.310000
# max           NaN         NaN              NaN         NaN     4.700000
#
#         Price (Euro)
# count    1275.000000
# unique           NaN
# top              NaN
# freq             NaN
# mean     1134.969059
# std       700.752504
# min       174.000000
# 25%       609.000000
# 50%       989.000000
# 75%      1496.500000
# max      6099.000000

# %%
df.dropna()
df[["Product", "Price (Euro)"]].describe(include="all")
# Out:
#        Product  Price (Euro)
# count     1275   1275.000000
# unique     618           NaN
# top     XPS 13           NaN
# freq        30           NaN
# mean       NaN   1134.969059
# std        NaN    700.752504
# min        NaN    174.000000
# 25%        NaN    609.000000
# 50%        NaN    989.000000
# 75%        NaN   1496.500000
# max        NaN   6099.000000

# %%
result = df.groupby('Product')['Price (Euro)'].agg(['mean', 'max'])
print(result)
# Out:
#                                        mean     max
# Product
# 110-15ACL (A6-7310/4GB/500GB/W10)     298.0   298.0
# 14-am079na (N3710/8GB/2TB/W10)        389.0   389.0
# 15-AC110nv (i7-6500U/6GB/1TB/Radeon   764.0   764.0
# 15-AY023na (N3710/8GB/2TB/W10)        389.0   389.0
# 15-BA015wm (E2-7110/4GB/500GB/W10)    297.0   297.0
# ...                                     ...     ...
# Zenbook UX330UA-AH5Q                 1129.0  1129.0
# Zenbook UX390UA                      1950.0  1950.0
# Zenbook UX410UA-GV027T                945.0   945.0
# Zenbook UX430UA                      1049.0  1049.0
# Zenbook UX510UW-FI095T               1299.0  1299.0
#
# [618 rows x 2 columns]
